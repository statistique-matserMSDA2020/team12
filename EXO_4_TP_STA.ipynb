# %%
"""
MEMBRES DU GROUPE:
CHEIKH MBACKE DIOUF
ROKHAYA GUEYE
PAPE MOUSSA GUEYE
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Le  n est nombre d'essai qui ont été realisé:
n=10000

#la position(abcisse et ordonnée) de l'impact choisie aleatoirement selon une loi uniforme: 
x=np.random.uniform(low=0, high=1, size=[n,1])
y=np.random.uniform(low=0, high=1, size=[n,1])

#les points qui impacterons dans le cercle de rayon =1
point=y**2<=1-x**2

#estimation de pi/4
pie_sur4=np.sum(plus)/N
print("VALEUR ESTIMEE DE PI/4:", pie_sur4,"POUR n=10000")
print("VRAIE VALEUR DE PI/4:", np.pi/4)

xpoint=x[point]
ypoint=y[point]
plt.figure(figsize=[5,5])
plt.scatter(x, y, s=6)
plt.scatter(xpoint,ypoint, color='y', s=6)
plt.grid()
plt.show()
# Out:
# VALEUR ESTIMEE DE PI/4: 0.788 POUR n=10000
# VRAIE VALEUR DE PI/4: 0.7853981633974483

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Le  n est nombre d'essai qui ont été realisé:
n=1000

#la position(abcisse et ordonnée) de l'impact choisie aleatoirement selon une loi uniforme: 
x=np.random.uniform(low=0, high=1, size=[n,1])
y=np.random.uniform(low=0, high=1, size=[n,1])

#les points qui impacterons dans le cercle de rayon =1
point=y**2<=1-x**2

#estimation de pi/4
pie_sur4=np.sum(plus)/N
print("VALEUR ESTIMEE DE PI/4:", pie_sur4,"POUR n=1000")
print("VRAIE VALEUR DE PI/4:", np.pi/4)

xpoint=x[point]
ypoint=y[point]
plt.figure(figsize=[5,5])
plt.scatter(x, y, s=6)
plt.scatter(xpoint,ypoint, color='y', s=6)
plt.grid()
plt.show()
# Out:
# VALEUR ESTIMEE DE PI/4: 0.788 POUR n=1000
# VRAIE VALEUR DE PI/4: 0.7853981633974483

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Le  n est nombre d'essai qui ont été realisé:
n=100

#la position(abcisse et ordonnée) de l'impact choisie aleatoirement selon une loi uniforme: 
x=np.random.uniform(low=0, high=1, size=[n,1])
y=np.random.uniform(low=0, high=1, size=[n,1])

#les points qui impacterons dans le cercle de rayon =1
point=y**2<=1-x**2

#estimation de pi/4
pie_sur4=np.sum(plus)/N
print("VALEUR ESTIMEE DE PI/4:", pie_sur4,"POUR n=100")
print("VRAIE VALEUR DE PI/4:", np.pi/4)

xpoint=x[point]
ypoint=y[point]
plt.figure(figsize=[5,5])
plt.scatter(x, y, s=6)
plt.scatter(xpoint,ypoint, color='y', s=6)
plt.grid()
plt.show()
# Out:
# VALEUR ESTIMEE DE PI/4: 0.788 POUR n=100
# VRAIE VALEUR DE PI/4: 0.7853981633974483
