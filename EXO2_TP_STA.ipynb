# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# TRAVAILLONS VITE ET BIEN LE TEMPS C'EST LA VIE

xi=[18, 7, 14, 31, 21, 5, 11, 16, 26, 29]
yi=[55, 17, 36, 85, 62, 18, 33, 41, 63, 87]
#VOICI  L'ESTIMATION DES VALEURS DE Y
yci=[50.2469512195122,20.164634146341474,
     39.3079268292683, 85.79878048780486,
     58.451219512195124, 4.695121951219525, 
     31.103658536585375, 44.77743902439025,
     72.125, 80.32926829268291]
X = np.array(xi)
Y = np.array(yi)
YC=(2.734756097560975)*X+1.0213414634146503  
axes = plt.axes()
 # dessiner une grille par la fonction grid()
axes.grid()
# X et Y sont les variables 
plt.scatter(X,Y) 
plt.plot(X, YC, linewidth=4, color='b',label='yi/xi')
# afficher une legende pour mieux visualiser la regression
plt.legend()
plt.show()

#La moyennes de X 
moy1=X.mean() 
#La moyennes de Y

moy2=Y.mean()  

# variance de X :
var1=X.var()
# variance de Y: 
var2=Y.var()

# Ecarts types de X: 
ecart1=X.std()
# Ecarts types de Y: 
ecart2=Y.std()

#Calcule de la convariance entre X et Y
def cov(X, Y): 
    sum = 0 
    for n in range(0, len(X)): 
        sum += (X[n]) * (Y[n])
    return (sum/(len(X)))-moy1*moy2
covariance=cov(X,Y)

#Le coefficient de correllation r est: 
r=covariance/(ecart1*ecart2)

# calcule des coefficients a et b de la droite de regression par la methode des moindres carrées es
a=covariance/v1
b=moy2-a*moy1

# Afficher les moyenne 1
print(moy1)
# Afficher les moyenne 2
print(moy2) 
# Affichage de la variance var1
print(var1) 
# Affichage de la variance var2
print(var2)  
# Affichage des ecart-types:
print(ecart1)   
print(ecart2)    
# Affichage de la covariance 
print(covariance)  
# Affichage du coefficient de correlation 
print(r)            
## Affichage des coefficients a et b :
print(a)           
print(b)          

#la droite de regression des moindres carrés est:Y=(2.734756097560975)*X+1.0213414634146503

def val(): 
    for re in range(0, len(X)):
        return (2.734756097560975)*X[re]+1.0213414634146503   
C=val()

#Les valeurs corrigéés de Y
for reg in range(0, len(X)):
        c=(2.734756097560975)*X[reg]+1.0213414634146503   
        print(c)
#yci=[50.2469512195122,20.164634146341474, 39.3079268292683, 85.79878048780486, 58.451219512195124, 4.695121951219525, 31.103658536585375, 44.77743902439025,72.125, 80.32926829268291]

#une estimation plausible de Y à xi =21
Y21=(2.734756097560975)*21+1.0213414634146503 
print(Y21) # A x=21 

#calcul de l'ecart entre les deux valeurs de Y
ec=Y[4]-Y21
print(ec) 

"""La droite de régression de Y en fonction de X (Y=2.734756097560975)*X + 1.0213414634146503   )
verifie l'hypothèse que les valeurs de Y dépendent de celles de X,
c'est-à-dire  que la connaissance des valeurs de X permet d'estimer
les valeurs de Y. Il s'agit donc d'un modèle de prévision
et l'objectif est de minimiser l'erreur de prévision c'est-à-dire la distance entre les valeurs Yi observées et 
les valeurs Yci estimées par la relation. 
Les résidus seront donc la distance à la droite par rapport à l'axe des y."""

"""oui la droite des moindres carrés obtenue en 2 passe par le point moyen G(moy1,moy2)
 avec moy1=moyenne de xi et moy2=moyenne de yi. 
ceci peut etre generalisé carle coefficient b de la droite de regression des moindres carrées
est obtenu en verifiant la relation b=moy2-a*moy1. Cela permet de deduire la relation 
a=(Y-moy2)/(X-moy1) toute droite de regression verifie cette relation 
donc cette conclusion peut etre generalisée a n'importe laquelle droite de régression."""
# Out:
# 17.8
# 49.7
# 72.16
# 561.01
# 8.49470423263812
# 23.68564966387876
# 197.33999999999992
# 0.9808024912490334
# 2.734756097560975
# 1.0213414634146503
# 50.2469512195122
# 20.164634146341474
# 39.3079268292683
# 85.79878048780486
# 58.451219512195124
# 14.695121951219525
# 31.103658536585375
# 44.77743902439025
# 72.125
# 80.32926829268291
# 58.451219512195124
# 3.5487804878048763
# "oui la droite des moindres carrés obtenue en 2 passe par le point moyen G(moy1,moy2)\n avec moy1=moyenne de xi et moy2=moyenne de yi. \nceci peut etre generalisé carle coefficient b de la droite de regression des moindres carrées\nest obtenu en verifiant la relation b=moy2-a*moy1. Cela permet de deduire la relation \na=(Y-moy2)/(X-moy1) toute droite de regression verifie cette relation \ndonc cette conclusion peut etre generalisée a n'importe laquelle droite de régression."
